# %%
import sys
print(sys.prefix)
import os
print(os.getcwd())
# Out:
# C:\Users\User\.conda\envs\plotly_practice
# C:\Users\User

# %%
conda install pandas
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\User\.conda\envs\plotly_practice
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     intel-openmp-2023.1.0      |   h59b6b97_46319         2.7 MB
#     mkl-2023.1.0               |   h8bd8f75_46356       155.6 MB
#     mkl-service-2.4.0          |   py39h2bbff1b_1          45 KB
#     mkl_fft-1.3.6              |   py39hf11a4ad_1         160 KB
#     mkl_random-1.2.2           |   py39hf11a4ad_1         219 KB
#     numexpr-2.8.4              |   py39h7b80656_1         127 KB
#     numpy-1.24.3               |   py39h79a8e48_1          11 KB
#     numpy-base-1.24.3          |   py39h8a87ada_1         5.1 MB
#     pandas-1.5.3               |   py39hf11a4ad_0        10.5 MB
#     pytz-2022.7                |   py39haa95532_0         210 KB
#     tbb-2021.8.0               |       h59b6b97_0         149 KB
#     ------------------------------------------------------------
#                                            Total:       174.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/win-64::blas-1.0-mkl None
#   bottleneck         pkgs/main/win-64::bottleneck-1.3.5-py39h080aedc_0 None
#   intel-openmp       pkgs/main/win-64::intel-openmp-2023.1.0-h59b6b97_46319 None
#   mkl                pkgs/main/win-64::mkl-2023.1.0-h8bd8f75_46356 None
#   mkl-service        pkgs/main/win-64::mkl-service-2.4.0-py39h2bbff1b_1 None
#   mkl_fft            pkgs/main/win-64::mkl_fft-1.3.6-py39hf11a4ad_1 None
#   mkl_random         pkgs/main/win-64::mkl_random-1.2.2-py39hf11a4ad_1 None
#   numexpr            pkgs/main/win-64::numexpr-2.8.4-py39h7b80656_1 None
#   numpy              pkgs/main/win-64::numpy-1.24.3-py39h79a8e48_1 None
#   numpy-base         pkgs/main/win-64::numpy-base-1.24.3-py39h8a87ada_1 None
#   pandas             pkgs/main/win-64::pandas-1.5.3-py39hf11a4ad_0 None
#   pytz               pkgs/main/win-64::pytz-2022.7-py39haa95532_0 None
#   tbb                pkgs/main/win-64::tbb-2021.8.0-h59b6b97_0 None
#
#
#
# Downloading and Extracting Packages
#
# mkl-service-2.4.0    | 45 KB     |            |   0%
# mkl-service-2.4.0    | 45 KB     | ###5       |  36%
# mkl-service-2.4.0    | 45 KB     | ########## | 100%
# mkl-service-2.4.0    | 45 KB     | ########## | 100%
#
# intel-openmp-2023.1. | 2.7 MB    |            |   0%
# intel-openmp-2023.1. | 2.7 MB    | 1          |   2%
# intel-openmp-2023.1. | 2.7 MB    | 9          |  10%
# intel-openmp-2023.1. | 2.7 MB    | ###5       |  35%
# intel-openmp-2023.1. | 2.7 MB    | ######     |  60%
# intel-openmp-2023.1. | 2.7 MB    | #########9 |  99%
# intel-openmp-2023.1. | 2.7 MB    | ########## | 100%
#
# mkl-2023.1.0         | 155.6 MB  |            |   0%
# mkl-2023.1.0         | 155.6 MB  |            |   0%
# mkl-2023.1.0         | 155.6 MB  |            |   0%
# mkl-2023.1.0         | 155.6 MB  |            |   1%
# mkl-2023.1.0         | 155.6 MB  | 1          |   1%
# mkl-2023.1.0         | 155.6 MB  | 1          |   2%
# mkl-2023.1.0         | 155.6 MB  | 2          |   3%
# mkl-2023.1.0         | 155.6 MB  | 2          |   3%
# mkl-2023.1.0         | 155.6 MB  | 3          |   3%
# mkl-2023.1.0         | 155.6 MB  | 4          |   4%
# mkl-2023.1.0         | 155.6 MB  | 4          |   5%
# mkl-2023.1.0         | 155.6 MB  | 5          |   5%
# mkl-2023.1.0         | 155.6 MB  | 5          |   6%
# mkl-2023.1.0         | 155.6 MB  | 6          |   6%
# mkl-2023.1.0         | 155.6 MB  | 7          |   7%
# mkl-2023.1.0         | 155.6 MB  | 7          |   8%
# mkl-2023.1.0         | 155.6 MB  | 8          |   8%
# mkl-2023.1.0         | 155.6 MB  | 8          |   9%
# mkl-2023.1.0         | 155.6 MB  | 9          |   9%
# mkl-2023.1.0         | 155.6 MB  | 9          |  10%
# mkl-2023.1.0         | 155.6 MB  | #          |  10%
# mkl-2023.1.0         | 155.6 MB  | #          |  11%
# mkl-2023.1.0         | 155.6 MB  | #1         |  12%
# mkl-2023.1.0         | 155.6 MB  | #2         |  12%
# mkl-2023.1.0         | 155.6 MB  | #2         |  13%
# mkl-2023.1.0         | 155.6 MB  | #3         |  13%
# mkl-2023.1.0         | 155.6 MB  | #3         |  14%
# mkl-2023.1.0         | 155.6 MB  | #4         |  14%
# mkl-2023.1.0         | 155.6 MB  | #4         |  15%
# mkl-2023.1.0         | 155.6 MB  | #5         |  15%
# mkl-2023.1.0         | 155.6 MB  | #5         |  16%
# mkl-2023.1.0         | 155.6 MB  | #6         |  16%
# mkl-2023.1.0         | 155.6 MB  | #6         |  17%
# mkl-2023.1.0         | 155.6 MB  | #7         |  17%
# mkl-2023.1.0         | 155.6 MB  | #7         |  18%
# mkl-2023.1.0         | 155.6 MB  | #8         |  18%
# mkl-2023.1.0         | 155.6 MB  | #8         |  19%
# mkl-2023.1.0         | 155.6 MB  | #9         |  19%
# mkl-2023.1.0         | 155.6 MB  | #9         |  20%
# mkl-2023.1.0         | 155.6 MB  | ##         |  20%
# mkl-2023.1.0         | 155.6 MB  | ##1        |  21%
# mkl-2023.1.0         | 155.6 MB  | ##1        |  22%
# mkl-2023.1.0         | 155.6 MB  | ##2        |  22%
# mkl-2023.1.0         | 155.6 MB  | ##2        |  23%
# mkl-2023.1.0         | 155.6 MB  | ##3        |  23%
# mkl-2023.1.0         | 155.6 MB  | ##3        |  24%
# mkl-2023.1.0         | 155.6 MB  | ##4        |  24%
# mkl-2023.1.0         | 155.6 MB  | ##4        |  25%
# mkl-2023.1.0         | 155.6 MB  | ##5        |  25%
# mkl-2023.1.0         | 155.6 MB  | ##5        |  26%
# mkl-2023.1.0         | 155.6 MB  | ##6        |  26%
# mkl-2023.1.0         | 155.6 MB  | ##6        |  27%
# mkl-2023.1.0         | 155.6 MB  | ##7        |  27%
# mkl-2023.1.0         | 155.6 MB  | ##7        |  28%
# mkl-2023.1.0         | 155.6 MB  | ##8        |  28%
# mkl-2023.1.0         | 155.6 MB  | ##8        |  29%
# mkl-2023.1.0         | 155.6 MB  | ##9        |  30%
# mkl-2023.1.0         | 155.6 MB  | ###        |  30%
# mkl-2023.1.0         | 155.6 MB  | ###        |  30%
# mkl-2023.1.0         | 155.6 MB  | ###        |  31%
# mkl-2023.1.0         | 155.6 MB  | ###1       |  31%
# mkl-2023.1.0         | 155.6 MB  | ###1       |  32%
# mkl-2023.1.0         | 155.6 MB  | ###2       |  32%
# mkl-2023.1.0         | 155.6 MB  | ###2       |  33%
# mkl-2023.1.0         | 155.6 MB  | ###3       |  33%
# mkl-2023.1.0         | 155.6 MB  | ###3       |  34%
# mkl-2023.1.0         | 155.6 MB  | ###4       |  34%
# mkl-2023.1.0         | 155.6 MB  | ###4       |  35%
# mkl-2023.1.0         | 155.6 MB  | ###5       |  35%
# mkl-2023.1.0         | 155.6 MB  | ###6       |  36%
# mkl-2023.1.0         | 155.6 MB  | ###6       |  37%
# mkl-2023.1.0         | 155.6 MB  | ###7       |  37%
# mkl-2023.1.0         | 155.6 MB  | ###7       |  38%
# mkl-2023.1.0         | 155.6 MB  | ###8       |  38%
# mkl-2023.1.0         | 155.6 MB  | ###8       |  39%
# mkl-2023.1.0         | 155.6 MB  | ###9       |  39%
# mkl-2023.1.0         | 155.6 MB  | ####       |  40%
# mkl-2023.1.0         | 155.6 MB  | ####       |  41%
# mkl-2023.1.0         | 155.6 MB  | ####1      |  41%
# mkl-2023.1.0         | 155.6 MB  | ####1      |  42%
# mkl-2023.1.0         | 155.6 MB  | ####2      |  43%
# mkl-2023.1.0         | 155.6 MB  | ####3      |  43%
# mkl-2023.1.0         | 155.6 MB  | ####3      |  44%
# mkl-2023.1.0         | 155.6 MB  | ####4      |  44%
# mkl-2023.1.0         | 155.6 MB  | ####5      |  45%
# mkl-2023.1.0         | 155.6 MB  | ####5      |  46%
# mkl-2023.1.0         | 155.6 MB  | ####6      |  46%
# mkl-2023.1.0         | 155.6 MB  | ####7      |  47%
# mkl-2023.1.0         | 155.6 MB  | ####7      |  48%
# mkl-2023.1.0         | 155.6 MB  | ####8      |  48%
# mkl-2023.1.0         | 155.6 MB  | ####8      |  49%
# mkl-2023.1.0         | 155.6 MB  | ####9      |  49%
# mkl-2023.1.0         | 155.6 MB  | #####      |  50%
# mkl-2023.1.0         | 155.6 MB  | #####      |  51%
# mkl-2023.1.0         | 155.6 MB  | #####1     |  51%
# mkl-2023.1.0         | 155.6 MB  | #####1     |  52%
# mkl-2023.1.0         | 155.6 MB  | #####2     |  53%
# mkl-2023.1.0         | 155.6 MB  | #####3     |  53%
# mkl-2023.1.0         | 155.6 MB  | #####3     |  54%
# mkl-2023.1.0         | 155.6 MB  | #####4     |  54%
# mkl-2023.1.0         | 155.6 MB  | #####4     |  55%
# mkl-2023.1.0         | 155.6 MB  | #####5     |  56%
# mkl-2023.1.0         | 155.6 MB  | #####6     |  56%
# mkl-2023.1.0         | 155.6 MB  | #####6     |  57%
# mkl-2023.1.0         | 155.6 MB  | #####7     |  58%
# mkl-2023.1.0         | 155.6 MB  | #####8     |  58%
# mkl-2023.1.0         | 155.6 MB  | #####8     |  59%
# mkl-2023.1.0         | 155.6 MB  | #####9     |  60%
# mkl-2023.1.0         | 155.6 MB  | ######     |  60%
# mkl-2023.1.0         | 155.6 MB  | ######     |  61%
# mkl-2023.1.0         | 155.6 MB  | ######1    |  62%
# mkl-2023.1.0         | 155.6 MB  | ######2    |  62%
# mkl-2023.1.0         | 155.6 MB  | ######3    |  63%
# mkl-2023.1.0         | 155.6 MB  | ######3    |  64%
# mkl-2023.1.0         | 155.6 MB  | ######4    |  65%
# mkl-2023.1.0         | 155.6 MB  | ######5    |  65%
# mkl-2023.1.0         | 155.6 MB  | ######5    |  66%
# mkl-2023.1.0         | 155.6 MB  | ######6    |  67%
# mkl-2023.1.0         | 155.6 MB  | ######7    |  67%
# mkl-2023.1.0         | 155.6 MB  | ######8    |  68%
# mkl-2023.1.0         | 155.6 MB  | ######8    |  69%
# mkl-2023.1.0         | 155.6 MB  | ######9    |  69%
# mkl-2023.1.0         | 155.6 MB  | #######    |  70%
# mkl-2023.1.0         | 155.6 MB  | #######    |  71%
# mkl-2023.1.0         | 155.6 MB  | #######1   |  71%
# mkl-2023.1.0         | 155.6 MB  | #######2   |  72%
# mkl-2023.1.0         | 155.6 MB  | #######2   |  73%
# mkl-2023.1.0         | 155.6 MB  | #######3   |  73%
# mkl-2023.1.0         | 155.6 MB  | #######4   |  74%
# mkl-2023.1.0         | 155.6 MB  | #######4   |  75%
# mkl-2023.1.0         | 155.6 MB  | #######5   |  76%
# mkl-2023.1.0         | 155.6 MB  | #######6   |  76%
# mkl-2023.1.0         | 155.6 MB  | #######6   |  77%
# mkl-2023.1.0         | 155.6 MB  | #######7   |  78%
# mkl-2023.1.0         | 155.6 MB  | #######8   |  78%
# mkl-2023.1.0         | 155.6 MB  | #######9   |  79%
# mkl-2023.1.0         | 155.6 MB  | #######9   |  80%
# mkl-2023.1.0         | 155.6 MB  | ########   |  81%
# mkl-2023.1.0         | 155.6 MB  | ########1  |  81%
# mkl-2023.1.0         | 155.6 MB  | ########1  |  82%
# mkl-2023.1.0         | 155.6 MB  | ########2  |  83%
# mkl-2023.1.0         | 155.6 MB  | ########3  |  83%
# mkl-2023.1.0         | 155.6 MB  | ########4  |  84%
# mkl-2023.1.0         | 155.6 MB  | ########5  |  85%
# mkl-2023.1.0         | 155.6 MB  | ########5  |  86%
# mkl-2023.1.0         | 155.6 MB  | ########6  |  86%
# mkl-2023.1.0         | 155.6 MB  | ########7  |  87%
# mkl-2023.1.0         | 155.6 MB  | ########7  |  88%
# mkl-2023.1.0         | 155.6 MB  | ########8  |  89%
# mkl-2023.1.0         | 155.6 MB  | ########9  |  89%
# mkl-2023.1.0         | 155.6 MB  | #########  |  90%
# mkl-2023.1.0         | 155.6 MB  | #########  |  91%
# mkl-2023.1.0         | 155.6 MB  | #########1 |  91%
# mkl-2023.1.0         | 155.6 MB  | #########2 |  92%
# mkl-2023.1.0         | 155.6 MB  | #########2 |  93%
# mkl-2023.1.0         | 155.6 MB  | #########3 |  93%
# mkl-2023.1.0         | 155.6 MB  | #########3 |  94%
# mkl-2023.1.0         | 155.6 MB  | #########4 |  95%
# mkl-2023.1.0         | 155.6 MB  | #########5 |  95%
# mkl-2023.1.0         | 155.6 MB  | #########5 |  96%
# mkl-2023.1.0         | 155.6 MB  | #########6 |  96%
# mkl-2023.1.0         | 155.6 MB  | #########7 |  97%
# mkl-2023.1.0         | 155.6 MB  | #########7 |  98%
# mkl-2023.1.0         | 155.6 MB  | #########8 |  98%
# mkl-2023.1.0         | 155.6 MB  | #########9 |  99%
# mkl-2023.1.0         | 155.6 MB  | #########9 | 100%
# mkl-2023.1.0         | 155.6 MB  | ########## | 100%
#
# mkl_fft-1.3.6        | 160 KB    |            |   0%
# mkl_fft-1.3.6        | 160 KB    | 9          |  10%
# mkl_fft-1.3.6        | 160 KB    | ########## | 100%
# mkl_fft-1.3.6        | 160 KB    | ########## | 100%
#
# numexpr-2.8.4        | 127 KB    |            |   0%
# numexpr-2.8.4        | 127 KB    | #2         |  13%
# numexpr-2.8.4        | 127 KB    | ########## | 100%
# numexpr-2.8.4        | 127 KB    | ########## | 100%
#
# numpy-1.24.3         | 11 KB     |            |   0%
# numpy-1.24.3         | 11 KB     | ########## | 100%
# numpy-1.24.3         | 11 KB     | ########## | 100%
#
# mkl_random-1.2.2     | 219 KB    |            |   0%
# mkl_random-1.2.2     | 219 KB    | 7          |   7%
# mkl_random-1.2.2     | 219 KB    | ########## | 100%
# mkl_random-1.2.2     | 219 KB    | ########## | 100%
#
# numpy-base-1.24.3    | 5.1 MB    |            |   0%
# numpy-base-1.24.3    | 5.1 MB    | 1          |   1%
# numpy-base-1.24.3    | 5.1 MB    | #5         |  15%
# numpy-base-1.24.3    | 5.1 MB    | ##3        |  24%
# numpy-base-1.24.3    | 5.1 MB    | ####7      |  47%
# numpy-base-1.24.3    | 5.1 MB    | ######4    |  64%
# numpy-base-1.24.3    | 5.1 MB    | ########3  |  84%
# numpy-base-1.24.3    | 5.1 MB    | ########## | 100%
# numpy-base-1.24.3    | 5.1 MB    | ########## | 100%
#
# tbb-2021.8.0         | 149 KB    |            |   0%
# tbb-2021.8.0         | 149 KB    | #######5   |  75%
# tbb-2021.8.0         | 149 KB    | ########## | 100%
#
# pytz-2022.7          | 210 KB    |            |   0%
# pytz-2022.7          | 210 KB    | 7          |   8%
# pytz-2022.7          | 210 KB    | ########## | 100%
# pytz-2022.7          | 210 KB    | ########## | 100%
#
# pandas-1.5.3         | 10.5 MB   |            |   0%
# pandas-1.5.3         | 10.5 MB   |            |   0%
# pandas-1.5.3         | 10.5 MB   | 6          |   6%
# pandas-1.5.3         | 10.5 MB   | #4         |  15%
# pandas-1.5.3         | 10.5 MB   | ##4        |  25%
# pandas-1.5.3         | 10.5 MB   | ###3       |  34%
# pandas-1.5.3         | 10.5 MB   | ####4      |  44%
# pandas-1.5.3         | 10.5 MB   | #####4     |  54%
# pandas-1.5.3         | 10.5 MB   | ######4    |  65%
# pandas-1.5.3         | 10.5 MB   | #######4   |  75%
# pandas-1.5.3         | 10.5 MB   | ########6  |  86%
# pandas-1.5.3         | 10.5 MB   | #########6 |  97%
# pandas-1.5.3         | 10.5 MB   | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
print(pd.__version__)
# Out:
# 1.5.3

# %%
conda install -c plotly chart-studio
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\User\.conda\envs\plotly_practice
#
#   added / updated specs:
#     - chart-studio
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2023.5.7           |   py39haa95532_0         153 KB
#     chart-studio-1.1.0         |             py_0          50 KB  plotly
#     cryptography-39.0.1        |   py39h21b164f_0         1.0 MB
#     plotly-5.14.1              |             py_0         7.1 MB  plotly
#     pyopenssl-23.0.0           |   py39haa95532_0          97 KB
#     requests-2.29.0            |   py39haa95532_0          97 KB
#     retrying-1.3.3             |     pyhd3eb1b0_2          14 KB
#     tenacity-8.2.2             |   py39haa95532_0          37 KB
#     urllib3-1.26.15            |   py39haa95532_0         194 KB
#     ------------------------------------------------------------
#                                            Total:         8.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotlipy           pkgs/main/win-64::brotlipy-0.7.0-py39h2bbff1b_1003 None
#   certifi            pkgs/main/win-64::certifi-2023.5.7-py39haa95532_0 None
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0 None
#   chart-studio       plotly/noarch::chart-studio-1.1.0-py_0 None
#   cryptography       pkgs/main/win-64::cryptography-39.0.1-py39h21b164f_0 None
#   plotly             plotly/noarch::plotly-5.14.1-py_0 None
#   pyopenssl          pkgs/main/win-64::pyopenssl-23.0.0-py39haa95532_0 None
#   pysocks            pkgs/main/win-64::pysocks-1.7.1-py39haa95532_0 None
#   requests           pkgs/main/win-64::requests-2.29.0-py39haa95532_0 None
#   retrying           pkgs/main/noarch::retrying-1.3.3-pyhd3eb1b0_2 None
#   tenacity           pkgs/main/win-64::tenacity-8.2.2-py39haa95532_0 None
#   urllib3            pkgs/main/win-64::urllib3-1.26.15-py39haa95532_0 None
#   win_inet_pton      pkgs/main/win-64::win_inet_pton-1.1.0-py39haa95532_0 None
#
#
#
# Downloading and Extracting Packages
#
# requests-2.29.0      | 97 KB     |            |   0%
# requests-2.29.0      | 97 KB     | #6         |  17%
# requests-2.29.0      | 97 KB     | ########## | 100%
# requests-2.29.0      | 97 KB     | ########## | 100%
#
# cryptography-39.0.1  | 1.0 MB    |            |   0%
# cryptography-39.0.1  | 1.0 MB    | 1          |   2%
# cryptography-39.0.1  | 1.0 MB    | ##2        |  23%
# cryptography-39.0.1  | 1.0 MB    | ########1  |  81%
# cryptography-39.0.1  | 1.0 MB    | ########## | 100%
#
# tenacity-8.2.2       | 37 KB     |            |   0%
# tenacity-8.2.2       | 37 KB     | ####3      |  43%
# tenacity-8.2.2       | 37 KB     | ########## | 100%
# tenacity-8.2.2       | 37 KB     | ########## | 100%
#
# plotly-5.14.1        | 7.1 MB    |            |   0%
# plotly-5.14.1        | 7.1 MB    | ########## | 100%
# plotly-5.14.1        | 7.1 MB    | ########## | 100%
#
# certifi-2023.5.7     | 153 KB    |            |   0%
# certifi-2023.5.7     | 153 KB    | #          |  10%
# certifi-2023.5.7     | 153 KB    | ########## | 100%
# certifi-2023.5.7     | 153 KB    | ########## | 100%
#
# pyopenssl-23.0.0     | 97 KB     |            |   0%
# pyopenssl-23.0.0     | 97 KB     | ########## | 100%
# pyopenssl-23.0.0     | 97 KB     | ########## | 100%
#
# retrying-1.3.3       | 14 KB     |            |   0%
# retrying-1.3.3       | 14 KB     | ########## | 100%
# retrying-1.3.3       | 14 KB     | ########## | 100%
#
# urllib3-1.26.15      | 194 KB    |            |   0%
# urllib3-1.26.15      | 194 KB    | #######4   |  74%
# urllib3-1.26.15      | 194 KB    | ########## | 100%
#
# chart-studio-1.1.0   | 50 KB     |            |   0%
# chart-studio-1.1.0   | 50 KB     | ########## | 100%
# chart-studio-1.1.0   | 50 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
conda install -c conda-forge cufflinks-py
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\User\.conda\envs\plotly_practice
#
#   added / updated specs:
#     - cufflinks-py
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.5.7   |       h56e8100_0         145 KB  conda-forge
#     certifi-2023.5.7           |     pyhd8ed1ab_0         149 KB  conda-forge
#     colorlover-0.3.0           |             py_0          12 KB  conda-forge
#     cufflinks-py-0.17.3        |             py_0           4 KB  conda-forge
#     ipywidgets-8.0.6           |     pyhd8ed1ab_0         110 KB  conda-forge
#     jupyterlab_widgets-3.0.7   |     pyhd8ed1ab_1         169 KB  conda-forge
#     python-cufflinks-0.17.3    |             py_0          59 KB  conda-forge
#     widgetsnbextension-4.0.7   |     pyhd8ed1ab_0         828 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   colorlover         conda-forge/noarch::colorlover-0.3.0-py_0 None
#   cufflinks-py       conda-forge/noarch::cufflinks-py-0.17.3-py_0 None
#   ipywidgets         conda-forge/noarch::ipywidgets-8.0.6-pyhd8ed1ab_0 None
#   jupyterlab_widgets conda-forge/noarch::jupyterlab_widgets-3.0.7-pyhd8ed1ab_1 None
#   python-cufflinks   conda-forge/noarch::python-cufflinks-0.17.3-py_0 None
#   widgetsnbextension conda-forge/noarch::widgetsnbextension-4.0.7-pyhd8ed1ab_0 None
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2023.5.7-h56e8100_0 None
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/win-64::certifi-2023.5.7-py~ --> conda-forge/noarch::certifi-2023.5.7-pyhd8ed1ab_0 None
#
#
#
# Downloading and Extracting Packages
#
# ca-certificates-2023 | 145 KB    |            |   0%
# ca-certificates-2023 | 145 KB    | #1         |  11%
# ca-certificates-2023 | 145 KB    | #######7   |  77%
# ca-certificates-2023 | 145 KB    | ########## | 100%
#
# python-cufflinks-0.1 | 59 KB     |            |   0%
# python-cufflinks-0.1 | 59 KB     | ##7        |  27%
# python-cufflinks-0.1 | 59 KB     | ########## | 100%
# python-cufflinks-0.1 | 59 KB     | ########## | 100%
#
# certifi-2023.5.7     | 149 KB    |            |   0%
# certifi-2023.5.7     | 149 KB    | #          |  11%
# certifi-2023.5.7     | 149 KB    | ########## | 100%
# certifi-2023.5.7     | 149 KB    | ########## | 100%
#
# colorlover-0.3.0     | 12 KB     |            |   0%
# colorlover-0.3.0     | 12 KB     | ########## | 100%
# colorlover-0.3.0     | 12 KB     | ########## | 100%
#
# ipywidgets-8.0.6     | 110 KB    |            |   0%
# ipywidgets-8.0.6     | 110 KB    | #4         |  15%
# ipywidgets-8.0.6     | 110 KB    | ########## | 100%
# ipywidgets-8.0.6     | 110 KB    | ########## | 100%
#
# cufflinks-py-0.17.3  | 4 KB      |            |   0%
# cufflinks-py-0.17.3  | 4 KB      | ########## | 100%
# cufflinks-py-0.17.3  | 4 KB      | ########## | 100%
#
# widgetsnbextension-4 | 828 KB    |            |   0%
# widgetsnbextension-4 | 828 KB    | 1          |   2%
# widgetsnbextension-4 | 828 KB    | #####9     |  60%
# widgetsnbextension-4 | 828 KB    | ########## | 100%
# widgetsnbextension-4 | 828 KB    | ########## | 100%
#
# jupyterlab_widgets-3 | 169 KB    |            |   0%
# jupyterlab_widgets-3 | 169 KB    | 9          |   9%
# jupyterlab_widgets-3 | 169 KB    | ########## | 100%
# jupyterlab_widgets-3 | 169 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
conda install seaborn
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\User\.conda\envs\plotly_practice
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     contourpy-1.0.5            |   py39h59b6b97_0         159 KB
#     giflib-5.2.1               |       h8cc25b3_3          88 KB
#     jpeg-9e                    |       h2bbff1b_1         320 KB
#     kiwisolver-1.4.4           |   py39hd77b12b_0          60 KB
#     libdeflate-1.17            |       h2bbff1b_0         151 KB
#     libpng-1.6.39              |       h8cc25b3_0         369 KB
#     libtiff-4.5.0              |       h6c2663c_2         1.2 MB
#     libwebp-1.2.4              |       hbc33d0d_1          73 KB
#     libwebp-base-1.2.4         |       h2bbff1b_1         304 KB
#     lz4-c-1.9.4                |       h2bbff1b_0         143 KB
#     matplotlib-base-3.7.1      |   py39hf11a4ad_1         6.5 MB
#     pillow-9.4.0               |   py39hd77b12b_0        1000 KB
#     pyparsing-3.0.9            |   py39haa95532_0         152 KB
#     seaborn-0.12.2             |   py39haa95532_0         483 KB
#     xz-5.4.2                   |       h8cc25b3_0         592 KB
#     zstd-1.5.5                 |       hd43e919_0         682 KB
#     ------------------------------------------------------------
#                                            Total:        12.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             pkgs/main/win-64::brotli-1.0.9-h2bbff1b_7 None
#   brotli-bin         pkgs/main/win-64::brotli-bin-1.0.9-h2bbff1b_7 None
#   contourpy          pkgs/main/win-64::contourpy-1.0.5-py39h59b6b97_0 None
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0 None
#   fonttools          pkgs/main/noarch::fonttools-4.25.0-pyhd3eb1b0_0 None
#   freetype           pkgs/main/win-64::freetype-2.12.1-ha860e81_0 None
#   giflib             pkgs/main/win-64::giflib-5.2.1-h8cc25b3_3 None
#   importlib_resourc~ pkgs/main/noarch::importlib_resources-5.2.0-pyhd3eb1b0_1 None
#   jpeg               pkgs/main/win-64::jpeg-9e-h2bbff1b_1 None
#   kiwisolver         pkgs/main/win-64::kiwisolver-1.4.4-py39hd77b12b_0 None
#   lerc               pkgs/main/win-64::lerc-3.0-hd77b12b_0 None
#   libbrotlicommon    pkgs/main/win-64::libbrotlicommon-1.0.9-h2bbff1b_7 None
#   libbrotlidec       pkgs/main/win-64::libbrotlidec-1.0.9-h2bbff1b_7 None
#   libbrotlienc       pkgs/main/win-64::libbrotlienc-1.0.9-h2bbff1b_7 None
#   libdeflate         pkgs/main/win-64::libdeflate-1.17-h2bbff1b_0 None
#   libpng             pkgs/main/win-64::libpng-1.6.39-h8cc25b3_0 None
#   libtiff            pkgs/main/win-64::libtiff-4.5.0-h6c2663c_2 None
#   libwebp            pkgs/main/win-64::libwebp-1.2.4-hbc33d0d_1 None
#   libwebp-base       pkgs/main/win-64::libwebp-base-1.2.4-h2bbff1b_1 None
#   lz4-c              pkgs/main/win-64::lz4-c-1.9.4-h2bbff1b_0 None
#   matplotlib-base    pkgs/main/win-64::matplotlib-base-3.7.1-py39hf11a4ad_1 None
#   munkres            pkgs/main/noarch::munkres-1.1.4-py_0 None
#   pillow             pkgs/main/win-64::pillow-9.4.0-py39hd77b12b_0 None
#   pyparsing          pkgs/main/win-64::pyparsing-3.0.9-py39haa95532_0 None
#   seaborn            pkgs/main/win-64::seaborn-0.12.2-py39haa95532_0 None
#   tk                 pkgs/main/win-64::tk-8.6.12-h2bbff1b_0 None
#   xz                 pkgs/main/win-64::xz-5.4.2-h8cc25b3_0 None
#   zstd               pkgs/main/win-64::zstd-1.5.5-hd43e919_0 None
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2023.5.7~ --> pkgs/main::ca-certificates-2023.01.10-haa95532_0 None
#   certifi            conda-forge/noarch::certifi-2023.5.7-~ --> pkgs/main/win-64::certifi-2023.5.7-py39haa95532_0 None
#
#
#
# Downloading and Extracting Packages
#
# matplotlib-base-3.7. | 6.5 MB    |            |   0%
# matplotlib-base-3.7. | 6.5 MB    |            |   0%
# matplotlib-base-3.7. | 6.5 MB    | 2          |   3%
# matplotlib-base-3.7. | 6.5 MB    | 9          |  10%
# matplotlib-base-3.7. | 6.5 MB    | ##4        |  25%
# matplotlib-base-3.7. | 6.5 MB    | ####1      |  41%
# matplotlib-base-3.7. | 6.5 MB    | #####5     |  55%
# matplotlib-base-3.7. | 6.5 MB    | ######8    |  69%
# matplotlib-base-3.7. | 6.5 MB    | ########3  |  84%
# matplotlib-base-3.7. | 6.5 MB    | #########6 |  97%
# matplotlib-base-3.7. | 6.5 MB    | ########## | 100%
#
# libwebp-base-1.2.4   | 304 KB    |            |   0%
# libwebp-base-1.2.4   | 304 KB    | 5          |   5%
# libwebp-base-1.2.4   | 304 KB    | ########## | 100%
# libwebp-base-1.2.4   | 304 KB    | ########## | 100%
#
# libpng-1.6.39        | 369 KB    |            |   0%
# libpng-1.6.39        | 369 KB    | ###        |  30%
# libpng-1.6.39        | 369 KB    | ########## | 100%
# libpng-1.6.39        | 369 KB    | ########## | 100%
#
# kiwisolver-1.4.4     | 60 KB     |            |   0%
# kiwisolver-1.4.4     | 60 KB     | ##6        |  27%
# kiwisolver-1.4.4     | 60 KB     | ########## | 100%
# kiwisolver-1.4.4     | 60 KB     | ########## | 100%
#
# contourpy-1.0.5      | 159 KB    |            |   0%
# contourpy-1.0.5      | 159 KB    | #          |  10%
# contourpy-1.0.5      | 159 KB    | ########## | 100%
# contourpy-1.0.5      | 159 KB    | ########## | 100%
#
# jpeg-9e              | 320 KB    |            |   0%
# jpeg-9e              | 320 KB    | 5          |   5%
# jpeg-9e              | 320 KB    | ########## | 100%
# jpeg-9e              | 320 KB    | ########## | 100%
#
# lz4-c-1.9.4          | 143 KB    |            |   0%
# lz4-c-1.9.4          | 143 KB    | ##2        |  22%
# lz4-c-1.9.4          | 143 KB    | ########## | 100%
# lz4-c-1.9.4          | 143 KB    | ########## | 100%
#
# pillow-9.4.0         | 1000 KB   |            |   0%
# pillow-9.4.0         | 1000 KB   | 1          |   2%
# pillow-9.4.0         | 1000 KB   | ########8  |  88%
# pillow-9.4.0         | 1000 KB   | ########## | 100%
#
# pyparsing-3.0.9      | 152 KB    |            |   0%
# pyparsing-3.0.9      | 152 KB    | ###1       |  32%
# pyparsing-3.0.9      | 152 KB    | ########## | 100%
# pyparsing-3.0.9      | 152 KB    | ########## | 100%
#
# zstd-1.5.5           | 682 KB    |            |   0%
# zstd-1.5.5           | 682 KB    | 4          |   5%
# zstd-1.5.5           | 682 KB    | ########## | 100%
# zstd-1.5.5           | 682 KB    | ########## | 100%
#
# xz-5.4.2             | 592 KB    |            |   0%
# xz-5.4.2             | 592 KB    | 5          |   5%
# xz-5.4.2             | 592 KB    | ########## | 100%
# xz-5.4.2             | 592 KB    | ########## | 100%
#
# seaborn-0.12.2       | 483 KB    |            |   0%
# seaborn-0.12.2       | 483 KB    | 3          |   3%
# seaborn-0.12.2       | 483 KB    | ########## | 100%
# seaborn-0.12.2       | 483 KB    | ########## | 100%
#
# libwebp-1.2.4        | 73 KB     |            |   0%
# libwebp-1.2.4        | 73 KB     | ##1        |  22%
# libwebp-1.2.4        | 73 KB     | ########## | 100%
# libwebp-1.2.4        | 73 KB     | ########## | 100%
#
# giflib-5.2.1         | 88 KB     |            |   0%
# giflib-5.2.1         | 88 KB     | #8         |  18%
# giflib-5.2.1         | 88 KB     | ########## | 100%
# giflib-5.2.1         | 88 KB     | ########## | 100%
#
# libdeflate-1.17      | 151 KB    |            |   0%
# libdeflate-1.17      | 151 KB    | ###1       |  32%
# libdeflate-1.17      | 151 KB    | ########## | 100%
# libdeflate-1.17      | 151 KB    | ########## | 100%
#
# libtiff-4.5.0        | 1.2 MB    |            |   0%
# libtiff-4.5.0        | 1.2 MB    | 2          |   3%
# libtiff-4.5.0        | 1.2 MB    | ######8    |  69%
# libtiff-4.5.0        | 1.2 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import cufflinks as cf
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
